# %%
# 전처리된 음성데이터로 학습을 진행합니다.
# 학습된 모델은 'PROJECT_DIR/qwen3_ft_output'에 저장됩니다.
# 학습시에는 자원을 많이 먹습니다. A100 추천

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 자신의 프로젝트 폴더 경로로 변경하세요
my_path = '/content/drive/MyDrive/비트메이트_TP01'
# %cd {my_path}

# !pip install -r requirements.txt
# !apt-get -qq update
# !apt-get -qq install -y sox libsox-fmt-all
# Out:
# /content/drive/MyDrive/비트메이트_TP01
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.10.0+cu128)
# Requirement already satisfied: torchaudio==2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: transformers==4.57.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.57.3)
# Requirement already satisfied: accelerate==1.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.12.0)
# Requirement already satisfied: bitsandbytes==0.49.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.49.2)
# Requirement already satisfied: safetensors==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: faster-whisper==1.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: librosa==0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: soundfile==0.13.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.13.1)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: qwen-tts==0.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (0.1.1)
# Requirement already satisfied: gradio==6.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (6.13.0)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (2.0.2)
# Requirement already satisfied: tqdm==4.67.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (4.67.3)
# Requirement already satisfied: huggingface_hub==0.36.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (0.22.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.12.0->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.2.1->-r requirements.txt (line 10)) (4.7.1)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.2.1->-r requirements.txt (line 10)) (1.25.1)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.12/dist-packages (from faster-whisper==1.2.1->-r requirements.txt (line 10)) (17.0.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.11.0->-r requirements.txt (line 13)) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile==0.13.1->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: sox in /usr/local/lib/python3.12/dist-packages (from qwen-tts==0.1.1->-r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from qwen-tts==0.1.1->-r requirements.txt (line 18)) (0.8.2)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.136.1)
# Requirement already satisfied: gradio-client==2.5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (3.11.8)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (2.12.3)
# Requirement already satisfied: pydub<1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.0.26)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (2025.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.52.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.24.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.13.0->-r requirements.txt (line 21)) (0.46.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.36.2->-r requirements.txt (line 26)) (1.4.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python->-r requirements.txt (line 15)) (1.0.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==6.13.0->-r requirements.txt (line 21)) (3.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile==0.13.1->-r requirements.txt (line 14)) (3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==6.13.0->-r requirements.txt (line 21)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==6.13.0->-r requirements.txt (line 21)) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==6.13.0->-r requirements.txt (line 21)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==6.13.0->-r requirements.txt (line 21)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio==6.13.0->-r requirements.txt (line 21)) (0.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa==0.11.0->-r requirements.txt (line 13)) (0.43.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.2.1->-r requirements.txt (line 10)) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.2.1->-r requirements.txt (line 10)) (5.29.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio==6.13.0->-r requirements.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio==6.13.0->-r requirements.txt (line 21)) (2026.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa==0.11.0->-r requirements.txt (line 13)) (4.9.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio==6.13.0->-r requirements.txt (line 21)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio==6.13.0->-r requirements.txt (line 21)) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.3->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.3->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa==0.11.0->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.10.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio==6.13.0->-r requirements.txt (line 21)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio==6.13.0->-r requirements.txt (line 21)) (0.1.2)
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# 설치 + 경로 설정 + 리포/모델 준비
from pathlib import Path
import subprocess
import sys
import os

# 기본 경로
PROJECT_DIR = Path("/content/drive/MyDrive/비트메이트_TP01")
SPEAKER = "jjy"

DATASET_DIR = PROJECT_DIR / "data" / "dataset" / f"wav_{SPEAKER}"
WAVS_DIR = DATASET_DIR / "wavs"
METADATA_PATH = DATASET_DIR / "metadata.txt"
REF_AUDIO_PATH = DATASET_DIR / "ref.wav"

MODEL_DIR = PROJECT_DIR / "models" / "Qwen3-TTS-12Hz-1.7B-Base"
TRAIN_RAW_JSONL = PROJECT_DIR / "train_raw.jsonl"
TRAIN_CODES_JSONL = PROJECT_DIR / "train_with_codes.jsonl"
LOG_DIR = PROJECT_DIR / "qwen3_logs"
FT_OUTPUT_DIR = PROJECT_DIR / "qwen3_ft_output" / SPEAKER

REPO_DIR = Path("/content/Qwen3-TTS")
FINETUNE_DIR = REPO_DIR / "finetuning"

# 설치 함수
def run(cmd, cwd=None):
    print(">", " ".join(map(str, cmd)))
    subprocess.run(list(map(str, cmd)), check=True, cwd=str(cwd) if cwd else None)

# Qwen3-TTS repo clone
if not REPO_DIR.exists():
    run(["git", "clone", "https://github.com/QwenLM/Qwen3-TTS.git", str(REPO_DIR)])

# base model 다운로드
from huggingface_hub import snapshot_download

MODEL_DIR.mkdir(parents=True, exist_ok=True)

if not any(MODEL_DIR.iterdir()):
    snapshot_download(
        repo_id="Qwen/Qwen3-TTS-12Hz-1.7B-Base",
        local_dir=str(MODEL_DIR),
        local_dir_use_symlinks=False,
    )

print("PROJECT_DIR :", PROJECT_DIR)
print("DATASET_DIR :", DATASET_DIR)
print("MODEL_DIR   :", MODEL_DIR)
print("FINETUNE_DIR:", FINETUNE_DIR)
# Out:
# PROJECT_DIR : /content/drive/MyDrive/비트메이트_TP01
# DATASET_DIR : /content/drive/MyDrive/비트메이트_TP01/data/dataset/wav_jjy
# MODEL_DIR   : /content/drive/MyDrive/비트메이트_TP01/models/Qwen3-TTS-12Hz-1.7B-Base
# FINETUNE_DIR: /content/Qwen3-TTS/finetuning

# %%
# metadata.txt → train_raw.jsonl 변환
from pathlib import Path
import json

# 필수 파일 체크
for p in [METADATA_PATH, REF_AUDIO_PATH, WAVS_DIR]:
    if not p.exists():
        raise FileNotFoundError(f"필수 경로 없음: {p}")

rows = []
missing_files = []

with METADATA_PATH.open("r", encoding="utf-8") as f:
    for line_no, line in enumerate(f, start=1):
        line = line.strip()
        if not line:
            continue

        if "|" not in line:
            print(f"[스킵] {line_no}번째 줄 형식 이상: {line}")
            continue

        fname, text = line.split("|", 1)
        audio_path = WAVS_DIR / fname

        if not audio_path.exists():
            missing_files.append(audio_path)
            continue

        rows.append({
            "audio": str(audio_path),
            "text": text.strip(),
            "ref_audio": str(REF_AUDIO_PATH),
        })

with TRAIN_RAW_JSONL.open("w", encoding="utf-8") as f:
    for row in rows:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

print("저장 완료:", TRAIN_RAW_JSONL)
print("유효 샘플 수:", len(rows))

if missing_files:
    print("\n없는 파일들(최대 20개):")
    for p in missing_files[:20]:
        print("-", p)
# Out:
# 저장 완료: /content/drive/MyDrive/비트메이트_TP01/train_raw.jsonl
# 유효 샘플 수: 85

# %%
# 데이터 준비 + sft 스크립트 패치 + 학습
from pathlib import Path

# 1) prepare_data 실행
run([
    sys.executable, "prepare_data.py",
    "--device", "cuda:0",
    "--tokenizer_model_path", "Qwen/Qwen3-TTS-Tokenizer-12Hz",
    "--input_jsonl", TRAIN_RAW_JSONL,
    "--output_jsonl", TRAIN_CODES_JSONL,
], cwd=FINETUNE_DIR)

# 2) Colab용 패치
SFT_SCRIPT = FINETUNE_DIR / "sft_12hz.py"
text = SFT_SCRIPT.read_text(encoding="utf-8")

text = text.replace('attn_implementation="flash_attention_2"', 'attn_implementation="sdpa"')
text = text.replace("attn_implementation='flash_attention_2'", "attn_implementation='sdpa'")

old = 'accelerator = Accelerator(gradient_accumulation_steps=4, mixed_precision="bf16", log_with="tensorboard")'
new = '''accelerator = Accelerator(
        gradient_accumulation_steps=4,
        mixed_precision="bf16",
        log_with="tensorboard",
        project_dir=r"''' + str(LOG_DIR) + '''"
    )'''

if old in text:
    text = text.replace(old, new)

SFT_SCRIPT.write_text(text, encoding="utf-8")
print("sft_12hz.py 패치 완료")

# 3) 학습 파라미터
batch_size = 1
lr = 2e-6
epochs = 4

FT_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
LOG_DIR.mkdir(parents=True, exist_ok=True)

# 4) 학습 실행
run([
    sys.executable, "sft_12hz.py",
    "--init_model_path", MODEL_DIR,
    "--output_model_path", FT_OUTPUT_DIR,
    "--train_jsonl", TRAIN_CODES_JSONL,
    "--batch_size", str(batch_size),
    "--lr", str(lr),
    "--num_epochs", str(epochs),
    "--speaker_name", SPEAKER,
], cwd=FINETUNE_DIR)

print("학습 완료")
print("출력 폴더:", FT_OUTPUT_DIR)
print("내용:", [p.name for p in FT_OUTPUT_DIR.iterdir()])
# Out:
# > /usr/bin/python3 prepare_data.py --device cuda:0 --tokenizer_model_path Qwen/Qwen3-TTS-Tokenizer-12Hz --input_jsonl /content/drive/MyDrive/비트메이트_TP01/train_raw.jsonl --output_jsonl /content/drive/MyDrive/비트메이트_TP01/train_with_codes.jsonl
# sft_12hz.py 패치 완료
# > /usr/bin/python3 sft_12hz.py --init_model_path /content/drive/MyDrive/비트메이트_TP01/models/Qwen3-TTS-12Hz-1.7B-Base --output_model_path /content/drive/MyDrive/비트메이트_TP01/qwen3_ft_output/jjy --train_jsonl /content/drive/MyDrive/비트메이트_TP01/train_with_codes.jsonl --batch_size 1 --lr 2e-06 --num_epochs 4 --speaker_name jjy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3065/1880642249.py in <cell line: 0>()
#      41
#      42 # 4) 학습 실행
# ---> 43 run([
#      44     sys.executable, "sft_12hz.py",
#      45     "--init_model_path", MODEL_DIR,
#
# /tmp/ipykernel_3065/13353368.py in run(cmd, cwd)
#      26 def run(cmd, cwd=None):
#      27     print(">", " ".join(map(str, cmd)))
# ---> 28     subprocess.run(list(map(str, cmd)), check=True, cwd=str(cwd) if cwd else None)
#      29
#      30 # Qwen3-TTS repo clone
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1199                 stderr = self.stderr.read()
#    1200                 self.stderr.close()
# -> 1201             self.wait()
#    1202         else:
#    1203             if timeout is not None:
#
# /usr/lib/python3.12/subprocess.py in wait(self, timeout)
#    1262             endtime = _time() + timeout
#    1263         try:
# -> 1264             return self._wait(timeout=timeout)
#    1265         except KeyboardInterrupt:
#    1266             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _wait(self, timeout)
#    2051                         if self.returncode is not None:
#    2052                             break  # Another thread waited.
# -> 2053                         (pid, sts) = self._try_wait(0)
#    2054                         # Check the pid and loop as waitpid has been known to
#    2055                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.12/subprocess.py in _try_wait(self, wait_flags)
#    2009             """All callers to this function MUST hold self._waitpid_lock."""
#    2010             try:
# -> 2011                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012             except ChildProcessError:
#    2013                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
# 체크포인트 테스트
from pathlib import Path
import torch
import soundfile as sf
from IPython.display import Audio, display
from qwen_tts import Qwen3TTSModel

TEST_TEXT = (
    "토끼와 거북이는 빠른 토끼가 느린 거북이를 얕보고 경주 도중 방심해 잠이 드는 사이, "
    "꾸준히 쉬지 않고 나아간 거북이가 결국 먼저 도착해 승리한다는 이야기로, "
    "재능이나 속도보다도 끝까지 성실하게 노력하는 태도가 더 중요하다는 교훈을 전한다."
)

checkpoint_dirs = sorted([
    p for p in FT_OUTPUT_DIR.iterdir()
    if p.is_dir() and p.name.startswith("checkpoint-epoch-")
])

if not checkpoint_dirs:
    raise FileNotFoundError(f"체크포인트 폴더가 없습니다: {FT_OUTPUT_DIR}")

for ckpt_path in checkpoint_dirs:
    weight_file = ckpt_path / "model.safetensors"
    if not weight_file.exists():
        print(f"{ckpt_path.name} -> skip (no weights)")
        continue

    print(f"\n===== {ckpt_path.name} =====")

    tts = Qwen3TTSModel.from_pretrained(
        str(ckpt_path),
        device_map="cuda:0" if torch.cuda.is_available() else "cpu",
        dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
    )

    wavs, sr = tts.generate_custom_voice(
        text=TEST_TEXT,
        speaker=SPEAKER,
    )

    out_path = FT_OUTPUT_DIR / f"{ckpt_path.name}.wav"
    sf.write(str(out_path), wavs[0], sr)

    print("저장:", out_path)
    display(Audio(str(out_path)))
